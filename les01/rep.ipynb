# %% [markdown]
# <a href="https://colab.research.google.com/github/timoshinArt/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Отчет о выполнении лабораторной работы № 1. Подготовка среды для анализа данных

# %% [markdown]
# ## Цель работы: настроить репозиторий для дальнейшего выполнения лабораторных работ в курсе

# %% [markdown]
# ### Ход выполнения работы

# %% [markdown]
# 1. Была создана учетная запись в сервисе GitHub и выполнен форк репозитория https://github.com/chebotarevsa/dap-2024.
# 2. После этого, в ранее созданной учетной записи Google была пройдена авторизация и настроена интеграция Google Colab и GitHub.
# 3. Далее, был создан отчет о выполненой работе в в Google Colab с названем rep.ipynb. Созданный отчет был добавлен в [репозиторий github](https://github.com/timoshinArt/dap-2024) в директории ./les01.
# 4. В завершении выполнения работы был создан pull request в репозиторий https://github.com/chebotarevsa/dap-2024.

# %% [markdown]
# ##Вывод

# %% [markdown]
# В ходе выполнения лабораторной работы был клонирован репозиторийи настроена интеграция между Google Colab и GitHub.
